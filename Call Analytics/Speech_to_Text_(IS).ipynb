# %%
# # from google.colab import files
# # uploaded = files.upload()
# from pydub import AudioSegment

# # Create an AudioSegment instance
# wav_file = AudioSegment.from_file(file= 'test.wav',
#                                   format="wav")

# # Check the type
# print(wav_file)

# import audiofile
# import wave
# import soundfile as sf
# import pathlib

# data, samplerate = sf.read(test_path)
# test_path = pathlib.Path('test.wav')
# # test = wave.open(test_path)
# #obj = wave.open('/Users/danielbabalola/Desktop/SFCU01-1616614738.758-IVR-0-+12157751684.wav','rb')

#!apt-get install sshpass -y

# !mkdir SFCU-speech
# %cd /content
# !sshpass -p 'Admirals75!' scp -o StrictHostKeyChecking=no -r daniel@10.55.1.247:/var/spool/asterisk/monitor/SFCU01-16170* ./Desktop

# filename = 'test.wav'
# r = sr.Recognizer()
# test = sr.AudioFile(filename)
# with test as source:
#   r.adjust_for_ambient_noise(source)
#   audio = r.record(source)
# text = r.recognize_google(audio)
# print(text)

# %%
# GITHUB_PRIVATE_KEY = """-----BEGIN OPENSSH PRIVATE KEY-----
# b3BlbnNzaC1rZXktdjEAAAAABG5vbmUAAAAEbm9uZQAAAAAAAAABAAAAMwAAAAtzc2gtZW
# QyNTUxOQAAACABOnrWqlUw9EHBL0QUuiMJqmmyr5KBTOsUjhEM6zGJvAAAAJAbFGcVGxRn
# FQAAAAtzc2gtZWQyNTUxOQAAACABOnrWqlUw9EHBL0QUuiMJqmmyr5KBTOsUjhEM6zGJvA
# AAAEDcCZsITFw0mq/kPEEjoqVEoRP9UmGy5jikI9dRNwUTAAE6etaqVTD0QcEvRBS6Iwmq
# abKvkoFM6xSOEQzrMYm8AAAACWp1bGlhQGp3MAECAwQ=
# -----END OPENSSH PRIVATE KEY-----

# """

# # Create the directory if it doesn't exist.
# ! mkdir -p /root/.ssh
# # Write the key
# f = open("/root/.ssh/id_ed25519", "w")
# f.write(GITHUB_PRIVATE_KEY)
# # Add github.com to our known hosts
# ! ssh-keyscan -t ed25519 github.com >> ~/.ssh/known_hosts
# # Restrict the key permissions, or else SSH will complain.
# ! chmod go-rwx /root/.ssh/id_ed25519

# # Note the `git@github.com` syntax, which will fetch over SSH instead of
# # HTTP.
# ! git clone git@github.com:julianweng/sfcu-private-call-demo.git
# Out:
# # github.com:22 SSH-2.0-babeld-ea310e90
# fatal: destination path 'sfcu-private-call-demo' already exists and is not an empty directory.

# %%
# path = "/content/sfcu-private-call-demo/SFCU01-1617030923.2159-IVR-2-+19734541945.wav"
# print("\nFull text:", get_large_audio_transcription(path))
# c = get_large_audio_transcription(path)
# Out:
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks/chunk6.wav : All of our representatives are currently busy.
# Error:
#
# Full text: All of our representatives are currently busy.

# %%
#  text = ("\nFull text:", get_large_audio_transcription(path))


# # text = re.findall('/: W', text)
# # text
# Out:
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks/chunk6.wav : All of our representatives are currently busy.
# Error:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pydub
# !pip install ffmpeg
# !pip install ffmpeg-python
# !pip install SpeechRecognition
# !pip install ffmpeg-normalize==0.5.1
# !pip install audiofile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6084 sha256=a33a0bd244440c30738c6a377d192e4c29ac91dc7d28adf24232185821fdd728
#   Stored in directory: /root/.cache/pip/wheels/30/33/46/5ab7eca55b9490dddbf3441c68a29535996270ef1ce8b9b6d7
# Successfully built ffmpeg
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 32.8 MB 1.3 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import speech_recognition as sr
import os
from pydub import AudioSegment
from pydub.silence import split_on_silence
import pandas as pd
import glob
import re
import pathlib

# %%
r = sr.Recognizer()

# %%
def get_large_audio_transcription(path):
    sound = AudioSegment.from_wav(path)
    chunks = split_on_silence(sound,
                              min_silence_len = 500,
                              silence_thresh = sound.dBFS-14,
                              keep_silence=500,
                             )
    folder_name = "audio-chunks"
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %%
filenames = glob.glob('/content/drive/MyDrive/SFCU Call Analytics/SFCU01-162_Part_Two/*')
filenames
# Out:
# ['/content/drive/MyDrive/SFCU Call Analytics/SFCU01-162_Part_Two/SFCU01-1625063758.5259-IVR-0-+12673530812.wav',
#  '/content/drive/MyDrive/SFCU Call Analytics/SFCU01-162_Part_Two/SFCU01-1625068404.5271-IVR-0-+12157155838.wav',
#  '/content/drive/MyDrive/SFCU Call Analytics/SFCU01-162_Part_Two/SFCU01-1625069266.5279-IVR-2-+17703597322.wav',
#  '/content/drive/MyDrive/SFCU Call Analytics/SFCU01-162_Part_Two/SFCU01-1625069970.5282-IVR-2-+12157155838.wav',
#  '/content/drive/MyDrive/SFCU Call Analytics/SFCU01-162_Part_Two/SFCU01-1625070076.5286-IVR-2-+12157155838.wav',
#  '/content/drive/MyDrive/SFCU Call Analytics/SFCU01-162_Part_Two/SFCU01-1625070189.5290-IVR-2-+12157155838.wav',
#  '/content/drive/MyDrive/SFCU Call Analytics/SFCU01-162_Part_Two/SFCU01-1625080947.5318-IVR-2-+12157155838.wav',
#  '/content/drive/MyDrive/SFCU Call Analytics/SFCU01-162_Part_Two/SFCU01-1625082349.5329-IVR-2-+12157155838.wav',
# ...

# %%
call_text_df = pd.DataFrame()

for i in filenames:
  text_beta = ("\nFull text:", get_large_audio_transcription(i))
  text = str(text_beta)
  call_text_df = pd.concat ([call_text_df,
            pd.DataFrame({'file' : [i],
                                  'text'   : [text]
                                          }
                                         )
    ])

call_text_df.to_csv('SFCU01-162_Pt_2.csv')
# !cp SFCU01-162_Pt_2.csv "/content/drive/MyDrive/SFCU Call Analytics"
# Out:
# Streaming output truncated to the last 5000 lines.
# audio-chunks/chunk65.wav : Thank you very much.
# Error:
# Error:
# Error:
# Error:
# audio-chunks/chunk3.wav : Hi this is karen samantha's few how can i help you.
# audio-chunks/chunk4.wav : Yes is this a philadelphia federal credit union.
# audio-chunks/chunk5.wav : No it's not.
# audio-chunks/chunk6.wav : Use a different credit union.
# audio-chunks/chunk7.wav : Coker.
# Error:
# Error:
# Error:
# audio-chunks/chunk3.wav : Hi this is karen smith.
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks/chunk14.wav : No i don't i can't get on the computer right now.
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks/chunk30.wav : Can i get your phone number.
# audio-chunks/chunk31.wav : My phone number on my account number.
# audio-chunks/chunk32.wav : Are your account number 72.
# ...

# %%
call_text_df
#call_text_df.to_csv(r'/content/SFCU01-161.csv')

# %%
call_text_path = pathlib.Path('/call_text_df-2.csv')
call_text_df = pd.read_csv(call_text_path)
#call_text_df.file = call_text_df.file.str.findall('SFCU.*')
call_text_df = call_text_df.drop(columns = 'Unnamed: 0')
call_text_df
# Out:
#                                                  file  \
# 0   ['SFCU01-1617223727.2954-IVR-2-+14848454061.wav']
# 1   ['SFCU01-1617391410.3520-IVR-0-+18582237092.wav']
# 2   ['SFCU01-1617127703.2593-IVR-2-+19734541945.wav']
# 3   ['SFCU01-1617030923.2159-IVR-2-+19734541945.wav']
# 4   ['SFCU01-1617217124.2906-IVR-2-+12152924886.wav']
# ..                                                ...
# 82  ['SFCU01-1617288761.3117-IVR-2-+14256989359.wav']
# 83   ['SFCU01-1617638525.599-IVR-2-+12155314976.wav']
# 84  ['SFCU01-1617133454.2613-IVR-2-+19788097213.wav']
# 85  ['SFCU01-1617034981.2225-IVR-2-+19734541945.wav']
# 86  ['SFCU01-1617809383.1239-IVR-0-+18889857280.wav']
#
#                                                  text
# 0   ('\nFull text:', "Don't do it. Please leave a ...
# 1   ('\nFull text:', "Hello internet to see how ca...
# 2   ('\nFull text:', "See how may i help you today...
# 3   ('\nFull text:', 'All of our representatives a...
# ...

# %%
# Analytics

# Code for identifying timestamp
import datetime
time_code = call_text_df.file
time_stamp =
['SFCU01-1617223727.2954-IVR-2-+14848454061.wav']
# Out:
# "('\\nFull text:', 'All of our representatives are currently busy. ')"

# %%
# cleaning text
# call_text_df['clean_text'] = list(i[18:-3] for i in call_text_df['text'])
# call_text_df = call_text_df.drop('text', axis=1)
# call_text_df = call_text_df.loc[call_text_df['clean_text' != ""]]
# call_text_df
call_text_df.text = call_text_df['text'].str.replace("('\nFull text:', '')", "")
call_text_df.dropna(subset = ['text'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                  file  \
# 0   ['SFCU01-1617223727.2954-IVR-2-+14848454061.wav']
# 1   ['SFCU01-1617391410.3520-IVR-0-+18582237092.wav']
# 2   ['SFCU01-1617127703.2593-IVR-2-+19734541945.wav']
# 3   ['SFCU01-1617030923.2159-IVR-2-+19734541945.wav']
# 4   ['SFCU01-1617217124.2906-IVR-2-+12152924886.wav']
# ..                                                ...
# 82  ['SFCU01-1617288761.3117-IVR-2-+14256989359.wav']
# 83   ['SFCU01-1617638525.599-IVR-2-+12155314976.wav']
# 84  ['SFCU01-1617133454.2613-IVR-2-+19788097213.wav']
# 85  ['SFCU01-1617034981.2225-IVR-2-+19734541945.wav']
# 86  ['SFCU01-1617809383.1239-IVR-0-+18889857280.wav']
#
#                                                  text
# 0   ('\nFull text:', "Don't do it. Please leave a ...
# ...

# %%
#  call_text_df.file.str.findall('SFCU.*')
call_text_df[call_text_df.apply(lambda row: row.astype(str).str.contains('close', case=False).any(), axis=1)]
# Out:
#                                                  file  \
# 6   ['SFCU01-1617214610.2890-IVR-2-+12673530812.wav']
# 30  ['SFCU01-1617207726.2843-IVR-2-+12196703092.wav']
# 79  ['SFCU01-1617038914.2249-IVR-2-+12196703092.wav']
#
#                                                  text
# 6   ('\nFull text:', "Closest to you how can i hel...
# 30  ('\nFull text:', "Hello to see how can i help ...
# 79  ('\nFull text:', "Little caesars on university...

# %%
#call_text_df.to_csv(r'/content/call_text_df.csv')

# %%
df_path = pathlib.Path('/content/drive/MyDrive/SFCU Call Analytics/SFCU01-161.csv')
df = pd.read_csv(df_path)

# %%
df1_path = pathlib.Path('/content/drive/MyDrive/SFCU Call Analytics/SFCU01-166.csv')
df1 = pd.read_csv(df1_path)

# %%
df = pd.concat([df,df1], axis = 0)

# %%
df = df.drop_duplicates(keep='first')
df = df.drop(columns = 'Unnamed: 0')
df
# Out:
#                                                   file  \
# 0    /content/drive/MyDrive/SFCU Call Analytics/SFC...
# 1    /content/drive/MyDrive/SFCU Call Analytics/SFC...
# 2    /content/drive/MyDrive/SFCU Call Analytics/SFC...
# 3    /content/drive/MyDrive/SFCU Call Analytics/SFC...
# 4    /content/drive/MyDrive/SFCU Call Analytics/SFC...
# ..                                                 ...
# 881  /content/drive/MyDrive/SFCU Call Analytics/SFC...
# 882  /content/drive/MyDrive/SFCU Call Analytics/SFC...
# 883  /content/drive/MyDrive/SFCU Call Analytics/SFC...
# 884  /content/drive/MyDrive/SFCU Call Analytics/SFC...
# 885  /content/drive/MyDrive/SFCU Call Analytics/SFC...
#
#                                                   text
# 0    ('\nFull text:', 'Are currently busy. Cleavage...
# 1    ('\nFull text:', 'Are currently busy. Please l...
# 2    ('\nFull text:', "Good morning mr. you haven't...
# 3    ('\nFull text:', "All of our representatives a...
# ...

# %%
df2_path = pathlib.Path('/content/drive/MyDrive/SFCU Call Analytics/SFCU01-161.csv')
df2 = pd.read_csv(df2_path)

# %%
 #df.to_csv(r'/content/call_analytics_df.csv')
df.to_csv('call_analytics_df.csv')
# !cp call_analytics_df.csv "/content/drive/MyDrive/SFCU Call Analytics"
